# %%
import numpy as np
import pandas as pd

# %%
a = 2

# %%
a
# Out:
# 2

# %%
b = a

# %%
b
# Out:
# 2

# %%
b = 3

# %%
a
# Out:
# 2

# %%
b = a

# %%
a
# Out:
# 2

# %%
b
# Out:
# 2

# %%
a = 4

# %%
b
# Out:
# 2
